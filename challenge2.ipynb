# %%
import numpy as np
import pandas as pd
import folium
from googletrans import Translator

# %%
df = pd.read_csv("data/problem 2 data.xlsx - Data.csv")
df.columns = [
    'id', 'start_date', 'end_date', 'record_date', 'lat', 'lng', 'governorate', 'district', 
    'registered', 'registration_type', 'business_name', 'economic_sector', 'sub_sector', 
    'products_services', 'phone_number', 'business_phone', 'employee_count', 'enterprise_size', 
    'has_vacancies', 'num_vacancies', 'current_interns', 'current_seasonal', 'current_entry_level', 
    'current_mid_senior', 'current_senior_mgmt', 'current_cust_service', 'current_sales', 
    'current_priority_it', 'current_priority_marketing', 'current_priority_admin', 'current_priority_finance', 
    'current_priority_logistics', 'current_priority_technical', 'current_priority_others', 'current_other_specify', 
    'youth_employment', 'future_needs', 'future_num_vacancies', 'future_interns', 'future_seasonal', 
    'future_entry_level', 'future_mid_senior', 'future_senior_mgmt', 'future_total', 'future_cust_service', 
    'future_sales', 'future_priority_it', 'future_priority_marketing', 'future_priority_admin', 
    'future_priority_finance', 'future_priority_logistics', 'future_priority_technical', 'future_priority_others', 
    'future_other_specify']
date_columns = ['start_date', 'end_date', 'record_date']
for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
data = df
translator = Translator()
arabic_columns = ['business_name', 'products_services', 'current_other_specify', 'future_other_specify']
def translate_column(column):
    return column.apply(lambda x: translator.translate(x, src='ar', dest='en').text if pd.notnull(x) else x)

for col in arabic_columns:
    data[col] = translate_column(data[col])
data.head()

# %%
data.head()
# Out:
#           id start_date   end_date record_date        lat        lng  \
# 0  376583921 2024-08-28 2024-08-28  2024-08-28  30.518529  35.570510
# 1  376583930 2024-08-28 2024-08-28  2024-08-28  30.518472  35.570386
# 2  376583936 2024-08-28 2024-08-28  2024-08-28  30.518922  35.573605
# 3  376583943 2024-08-28 2024-08-28  2024-08-28  30.518988  35.573454
# 4  376583950 2024-08-28 2024-08-28  2024-08-28  30.519855  35.574860
#
#   governorate    district registered    registration_type  ...  \
# 0        Maan  Ash-Shobek        Yes  Sole proprietorship  ...
# 1        Maan  Ash-Shobek        Yes  Sole proprietorship  ...
# 2        Maan  Ash-Shobek        Yes  Sole proprietorship  ...
# 3        Maan  Ash-Shobek        Yes  Sole proprietorship  ...
# 4        Maan  Ash-Shobek        Yes          Cooperative  ...
#
#   future_cust_service future_sales future_priority_it  \
# 0                   0            0                  0
# 1                   0            0                  0
# 2                   0            1                  0
# 3                   0            0                  1
# 4                   0            0                  0
#
#   future_priority_marketing future_priority_admin future_priority_finance  \
# 0                         0                     0                       0
# 1                         0                     0                       0
# 2                         0                     0                       0
# 3                         0                     0                       0
# 4                         0                     0                       0
#
#   future_priority_logistics future_priority_technical future_priority_others  \
# 0                         0                         0                      1
# 1                         0                         0                      1
# 2                         0                         0                      0
# 3                         0                         0                      0
# 4                         0                         0                      1
#
#                future_other_specify
# 0  ميكانيكي سيارات /عامل غيار زيوت
# 1                             حداد
# 2                               NaN
# 3                               NaN
# 4                 بائع كاشير /خباز
#
# [5 rows x 54 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1760 entries, 0 to 1759
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          1760 non-null   int64
#  1   start_date                  1760 non-null   datetime64[ns]
#  2   end_date                    1760 non-null   datetime64[ns]
#  3   record_date                 1760 non-null   datetime64[ns]
#  4   lat                         1760 non-null   float64
#  5   lng                         1760 non-null   float64
#  6   governorate                 1760 non-null   object
#  7   district                    1760 non-null   object
#  8   registered                  1760 non-null   object
#  9   registration_type           1524 non-null   object
#  10  business_name               1760 non-null   object
#  11  economic_sector             1760 non-null   object
#  12  sub_sector                  1760 non-null   object
#  13  products_services           1760 non-null   object
#  14  phone_number                1749 non-null   object
#  15  business_phone              641 non-null    object
#  16  employee_count              1760 non-null   object
#  17  enterprise_size             1760 non-null   object
#  18  has_vacancies               1760 non-null   object
#  19  num_vacancies               1760 non-null   int64
#  20  current_interns             1760 non-null   int64
#  21  current_seasonal            1760 non-null   int64
#  22  current_entry_level         1760 non-null   int64
#  23  current_mid_senior          1760 non-null   int64
#  24  current_senior_mgmt         1760 non-null   int64
#  25  current_cust_service        1760 non-null   int64
#  26  current_sales               1760 non-null   int64
#  27  current_priority_it         1760 non-null   int64
#  28  current_priority_marketing  1760 non-null   int64
#  29  current_priority_admin      1760 non-null   int64
#  30  current_priority_finance    1760 non-null   int64
#  31  current_priority_logistics  1760 non-null   int64
#  32  current_priority_technical  1760 non-null   int64
#  33  current_priority_others     1760 non-null   int64
#  34  current_other_specify       92 non-null     object
#  35  youth_employment            1760 non-null   object
#  36  future_needs                1760 non-null   object
#  37  future_num_vacancies        1760 non-null   int64
#  38  future_interns              1760 non-null   int64
#  39  future_seasonal             1760 non-null   int64
#  40  future_entry_level          1760 non-null   int64
#  41  future_mid_senior           1760 non-null   int64
#  42  future_senior_mgmt          1760 non-null   int64
#  43  future_total                1760 non-null   int64
#  44  future_cust_service         1760 non-null   int64
#  45  future_sales                1760 non-null   int64
#  46  future_priority_it          1760 non-null   int64
#  47  future_priority_marketing   1760 non-null   int64
#  48  future_priority_admin       1760 non-null   int64
#  49  future_priority_finance     1760 non-null   int64
#  50  future_priority_logistics   1760 non-null   int64
#  51  future_priority_technical   1760 non-null   int64
#  52  future_priority_others      1760 non-null   int64
#  53  future_other_specify        210 non-null    object
# dtypes: datetime64[ns](3), float64(2), int64(32), object(17)
# memory usage: 742.6+ KB

# %%
district_counts = df['district'].value_counts().reset_index()
district_counts.columns = ['district', 'business_count']

central_coords = df.groupby('district').agg({'lat': 'mean','lng': 'mean'}).reset_index()
central_coords.columns = ['district', 'Central Latitude', 'Central Longitude']

district_df = pd.merge(district_counts, central_coords, on='district', how='inner')

district_df
# Out:
#                  district  business_count  Central Latitude  Central Longitude
# 0                   Petra             151         30.305667          35.476001
# 1        Fuhais and Mahes             148         32.003366          35.785633
# 2        Aqaba Al-Qasabah             148         29.534848          35.006126
# 3       Mafraq Al-qasabeh             145         32.341822          36.210818
# 4          Jerash Qasabah             137         32.326744          35.893851
# 5          Ajloun Qasabah             125         32.332715          35.742472
# 6              Ash-Shobek             117         30.516729          35.552917
# 7               Al Dlayel             113         32.108437          36.247649
# 8                   Naour             108         31.886057          35.856042
# 9           Irbid Qasabah             101         32.550231          35.850257
# 10         Madaba Qasabah              92         31.717989          35.795757
# 11            Al-Qatraneh              83         31.253455          36.047791
# 12     Tafeleh Al-Qasabeh              72         30.805321          35.598125
# 13       Karak Al-Qasabah              52         31.169455          35.731262
# 14                 Dieban              52         31.500456          35.781593
# 15                 Koorah              45         32.501763          35.688357
# 16       Zarqa Al-Qasabeh              30         32.086563          36.098775
# 17                 Anjara              17         32.312763          35.758312
# 18  Al-Mazar al Jabubiyya               7         31.100416          35.714555
# 19                  Mlaih               5         31.604055          35.793209
# 20        Badiah Gharbiah               4         32.376236          36.242521
# 21                  Allan               2         32.004306          35.785090
# 22             Bani Obeid               2         32.508659          35.856665
# 23              Wastiyyah               1         32.554227          35.805939
# 24            Ghwr Alsafi               1         31.171161          35.727376
# 25                  Borma               1         32.273393          35.899565
# 26      Badiah Shamaliyah               1         32.341646          36.202000

# %%
# Create a base map centered around an approximate central location in Jordan
map_folium = folium.Map(location=[31.5852, 35.8623], zoom_start=7)

# Plot each district with the central latitude, longitude, and business count information
for index, row in district_df.iterrows():
    district = row['District']
    business_count = row['Business Count']
    lat = row['Central Latitude']
    lng = row['Central Longitude']
    
    # Add a marker for each district
    folium.Marker(
        location=[lat, lng],
        popup=f"{district}: {business_count} businesses",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(map_folium)

# Display the map
map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07942ca7ff1cf86470dc704f7cd8ddfe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07942ca7ff1cf86470dc704f7cd8ddfe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07942ca7ff1cf86470dc704f7cd8ddfe = L.map(
#                 &quot;map_07942ca7ff1cf86470dc704f7cd8ddfe&quot;,
#                 {
#                     center: [31.5852, 35.8623],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7084b60ac01efaf7a59304a3d0ee1a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_07942ca7ff1cf86470dc704f7cd8ddfe);
#
#
#             var marker_8269d68def49c551870ebab781d32323 = L.marker(
#                 [30.30566709456953, 35.47600079258281],
#                 {}
#             ).addTo(map_07942ca7ff1cf86470dc704f7cd8ddfe);
#
#
#             var icon_5d88d1ea5c2aaafed7ba06bf6b53e50c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8269d68def49c551870ebab781d32323.setIcon(icon_5d88d1ea5c2aaafed7ba06bf6b53e50c);
#
#
#         var popup_c9b535f4e9bcfe0a774c39cfdfb0146f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_203a4af58e36c8d5080efbd35f9fb6ee = $(`&lt;div id=&quot;html_203a4af58e36c8d5080efbd35f9fb6ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Petra: 151 businesses&lt;/div&gt;`)[0];
#                 popup_c9b535f4e9bcfe0a774c39cfdfb0146f.setContent(html_203a4af58e36c8d5080efbd35f9fb6ee);
#
#
#
#         marker_8269d68def49c551870ebab781d32323.bindPopup(popup_c9b535f4e9bcfe0a774c39cfdfb0146f)
#         ;
#
#
#
#
#             var marker_580b60342fa48bdd152e7a9ff2682eb1 = L.marker(
#                 [32.00336604256756, 35.78563285810811],
#                 {}
#             ).addTo(map_07942ca7ff1cf86470dc704f7cd8ddfe);
#
#
#             var icon_b18848f2c9f7435ec9dc546a905c8c2b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_580b60342fa48bdd152e7a9ff2682eb1.setIcon(icon_b18848f2c9f7435ec9dc546a905c8c2b);
#
#
#         var popup_8da49c3ee4c395372189c495d5bd49b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21bf5b973b95e0e94e4db8ab43ff2ea9 = $(`&lt;div id=&quot;html_21bf5b973b95e0e94e4db8ab43ff2ea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fuhais and Mahes: 148 businesses&lt;/div&gt;`)[0];
#                 popup_8da49c3ee4c395372189c495d5bd49b9.setContent(html_21bf5b973b95e0e94e4db8ab43ff2ea9);
#
#
#
#         marker_580b60342fa48bdd152e7a9ff2682eb1.bindPopup(popup_8da49c3ee4c395372189c495d5bd49b9)
#         ;
#
#
#
#
#             var marker_d06b5e244391601624650095d53e71fe = L.marker(
#                 [29.53484787905405, 35.00612637094601],
#                 {}
#             ).addTo(map_07942ca7ff1cf86470dc704f7cd8ddfe);
#
#
#             var icon_a289d42fd654202154075b1139046911 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d06b5e244391601624650095d53e71fe.setIcon(icon_a289d42fd654202154075b1139046911);
#
#
#         var popup_fe30b0af8ce77afe8bb94d4aaa76f262 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dde6b191578fdf2ed72e330e38ad8fc6 = $(`&lt;div id=&quot;html_dde6b191578fdf2ed72e330e38ad8fc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aqaba Al-Qasabah: 148 businesses&lt;/div&gt;`)[0];
#                 popup_fe30b0af8ce77afe8bb94d4aaa76f262.setContent(html_dde6b191578fdf2ed72e330e38ad8fc6);
#
#
#
#         marker_d06b5e244391601624650095d53e71fe.bindPopup(popup_fe30b0af8ce77afe8bb94d4aaa76f262)
#         ;
#
#
#
#
#             var marker_7bd07e9031f6a3ddacfe496e66d7e64f = L.marker(
#                 [32.341822262344834, 36.21081825344826],
#                 {}
#             ).addTo(map_07942ca7ff1cf86470dc704f7cd8ddfe);
#
#
#             var icon_03f3600326bf70f44e014d7ad0a4aedd = L.AwesomeMa
